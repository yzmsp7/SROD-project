# %%
from __future__ import absolute_import
from __future__ import print_function

import os
import re
import sys
import json
import requests
from bs4 import BeautifulSoup

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import csv
import time

# %%
import datetime
from datetime import timedelta

# %%
pushUrls = []
pushes = []
mergedPushes = []
userPushes = {}
article_href = []

# %%
r = requests.get("https://www.ptt.cc/bbs/Hate/index.html")
soup = BeautifulSoup(r.text, 'html.parser')
results = soup.select('div.title')
print(results)
# Out:
# [<div class="title">
# <a href="/bbs/Hate/M.1581756353.A.DC1.html">[黑特] 夢中夢</a>
# </div>, <div class="title">
# <a href="/bbs/Hate/M.1581756968.A.9EE.html">[黑特] [BM_NeedMoney] 發放01/22~02/04的獎勵</a>
# </div>, <div class="title">
# <a href="/bbs/Hate/M.1581756990.A.D57.html">[黑特] (本文已被刪除) [lin91223]</a>
# </div>, <div class="title">
# <a href="/bbs/Hate/M.1581757399.A.45F.html">[王八] 幹 身體不舒服 出來衝啥小？</a>
# </div>, <div class="title">
# <a href="/bbs/Hate/M.1581757526.A.AB7.html">今天</a>
# </div>, <div class="title">
# <a href="/bbs/Hate/M.1581757943.A.DF5.html">[黑特] 好噁</a>
# </div>, <div class="title">
# <a href="/bbs/Hate/M.1581758027.A.8C1.html">[黑特] 發文被記者抄了</a>
# </div>, <div class="title">
# <a href="/bbs/Hate/M.1581758836.A.EC9.html">[超幹] 3064</a>
# </div>, <div class="title">
# <a href="/bbs/Hate/M.1581759770.A.6A8.html">[黑特] 哀居</a>
# </div>, <div class="title">
# <a href="/bbs/Hate/M.1581760048.A.4DA.html">[黑特] 我下午</a>
# </div>, <div class="title">
# <a href="/bbs/Hate/M.1581760373.A.A7A.html">[黑特] (本文已被刪除) [lin91223]</a>
# </div>, <div class="title">
# <a href="/bbs/Hate/M.1581760966.A.F48.html">無知</a>
# </div>, <div class="title">
# <a href="/bbs/Hate/M.1581761008.A.EA6.html">[黑特] check in</a>
# </div>, <div class="title">
# <a href="/bbs/Hate/M.1441110720.A.630.html">[公告] 歷次板務宣導</a>
# </div>, <div class="title">
# <a href="/bbs/Hate/M.1549436508.A.443.html">[公告] 黑特板板規(2019.2.6)</a>
# </div>, <div class="title">
# <a href="/bbs/Hate/M.1575904608.A.705.html">[公告] 發文要有恨意、字數要足夠</a>
# </div>, <div class="title">
# <a href="/bbs/Hate/M.1580301233.A.734.html">[公告] 政治文回覆正常</a>
# </div>]

# %%
PTT_URL = 'https://www.ptt.cc/bbs'

# %%
def parse_articles(self, start, end, board, path='.', timeout=3):
    filename = board + '-' + str(start) + '-' + str(end) + '.json'

# %%
from pandas.io.json import json_normalize

with open('/Users/yuzhe/python_project/ptt-web-crawler/PttWebCrawler/Hate-1-200.json', 'r') as reader:
    jf = json.loads(reader.read())

df = json_normalize(jf['articles'])
df.article_title.unique()
# Out:
# array(['恨！我的野蠻室友', '什麼快樂星期天阿', '我好懦弱', ..., '[公告] double21 水桶',
#        '[公告] iamsg 水桶兩週', '[長恨] 初一早 初二早 初三失戀了'], dtype=object)

# %% [markdown]
# 全爬下來的話：
# 1. 文章有「公告」，做停權處置等等
# 2.

# %%
PTT_URL = 'https://www.ptt.cc'
board = 'Hate'
start_index = 1
end_index = 10

# %%
data = []

for i in range(end_index - start_index + 1):
    index = start_index + i
    print('Processcing index: ', str(index))
    
    resp = requests.get(url = PTT_URL + '/bbs/' + board + '/index' + str(index) + '.html',
                        cookies = {'over18':'1'})
    
    # status_code=200 is success, so if not success will return error e.g. 404 not found
    if resp.status_code != 200:
        print('invalid url: ', resp.url)
        continue
    
    # parser the html and find articles' div element
    soup = BeautifulSoup(resp.text, 'html.parser')
    divs = soup.find_all('div', 'r-ent')
    
    for div in divs:
        #try:
            href = div.find('a')['href']
            link = PTT_URL + href
            article_id = re.sub('\.html', '', href.split('/')[-1])
            
            print('Processing article: ', article_id)
            print('link', link)
            resp2 = requests.get(url = link, cookies={'over18':'1'})
            
            # status_code=200 is success, so if not success will return error e.g. 404 not found
            if resp2.status_code != 200:
                print('invalid url: ', resp2.url)

            soup2 = BeautifulSoup(resp2.text, 'html.parser')
            main_content2 = soup2.find(id = 'main-content')
            # metaline includes of author, title and datetime
            metas = main_content2.select('div.article-metaline')

            author = ''
            title = ''
            date = ''

            if metas:
                author = metas[0].select('span.article-meta-value')[0].string if metas[0].select('span.article-meta-value')[0] else author
                title = metas[1].select('span.article-meta-value')[0].string if metas[1].select('span.article-meta-value')[0] else title
                date = metas[2].select('span.article-meta-value')[0].string if metas[2].select('span.article-meta-value')[0] else date
                # remove meta nodes
                for meta in metas:
                    meta.extract()
                for meta in main_content2.select('div.article-metaline-right'):
                    meta.extract()
            # remove and keep push nodes
            for push in main_content2.find_all('div', class_='push'):
                push.extract()

            # 移除 '※ 發信站:' (starts with u'\u203b'), '◆ From:' (starts with u'\u25c6'), 空行及多餘空白
            # 保留英數字, 中文及中文標點, 網址, 部分特殊符號
            filtered = [ v for v in main_content2.stripped_strings if v[0] not in [u'※', u'◆'] and v[:2] not in [u'--'] ]
            expr = re.compile(u(r'[^\u4e00-\u9fa5\u3002\uff1b\uff0c\uff1a\u201c\u201d\uff08\uff09\u3001\uff1f\u300a\u300b\s\w:/-_.?~%()]'))
            for i in range(len(filtered)):
                filtered[i] = re.sub(expr, '', filtered[i])

            filtered = [_f for _f in filtered if _f]  # remove empty strings
            filtered = [x for x in filtered if article_id not in x]  # remove last line containing the url of the article
            content = ' '.join(filtered)
            content = re.sub(r'(\s)+', ' ', content)

            data = {
                'url': link,
                'title': title,
                'author': author,
                'date': date,
                'content': content
            }
            
        #except:
        #    pass
        
    time.sleep(0.1)
# Out:
# Processcing index:  1
# Processing article:  M.1049633636.A.41C
# link https://www.ptt.cc/bbs/Hate/M.1049633636.A.41C.html
# <div class="article-metaline"><span class="article-meta-tag">作者</span><span class="article-meta-value">Kaohsiung85 (東帝士85超高大樓)</span></div>
# <div class="article-metaline"><span class="article-meta-tag">標題</span><span class="article-meta-value">恨！我的野蠻室友</span></div>
# <div class="article-metaline"><span class="article-meta-tag">時間</span><span class="article-meta-value">Sun Apr  6 20:45:59 2003</span></div>
# <div class="article-metaline-right"><span class="article-meta-tag">看板</span><span class="article-meta-value">Hate</span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">StreetLight</span><span class="f3 push-content">:到底他做了什麼..你一件也沒講 @@</span><span class="push-ipdatetime">         推  140.112.21.41 04/07
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Kaohsiung85</span><span class="f3 push-content">:他就是亂罵人，他還想揍我！</span><span class="push-ipdatetime">              推 140.112.241.17 04/07
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Kaohsiung85</span><span class="f3 push-content">:他超賤，根本寫不完！</span><span class="push-ipdatetime">                    推 140.112.241.17 04/07
# </span></div>
# <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">helpmeoverit</span><span class="f3 push-content">:推</span><span class="push-ipdatetime">                                       218.166.169.120 07/25
# </span></div>
# <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">nisa</span><span class="f3 push-content">:住宿容易遇到賤人還有神經有問題的人</span><span class="push-ipdatetime">                218.161.59.180 08/21
# </span></div>
# <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">FranKang</span><span class="f3 push-content">:6</span><span class="push-ipdatetime">                                              218.184.20.37 11/06
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">FranKang</span><span class="f3 push-content">:6</span><span class="push-ipdatetime">                                              218.184.20.37 11/06
# </span></div>
# <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Koibito</span><span class="f3 push-content">:ζζ老媽手術成功  身體早日康復ζζ</span><span class="push-ipdatetime">            220.132.182.103 11/19
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">lightmyfire</span><span class="f3 push-content">:原PO是正妹</span><span class="push-ipdatetime"> 140.116.110.68 03/05
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">lightmyfire</span><span class="f3 push-content">:原PO是正妹</span><span class="push-ipdatetime"> 140.116.110.68 03/05
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">lightmyfire</span><span class="f3 push-content">:原PO是正妹</span><span class="push-ipdatetime"> 140.116.110.68 03/05
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">lightmyfire</span><span class="f3 push-content">:原PO是正妹</span><span class="push-ipdatetime"> 140.116.110.68 03/05
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">gunlinlaus</span><span class="f3 push-content">:orz.3</span><span class="push-ipdatetime">   140.112.7.59 06/25
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">LostHeaven</span><span class="f3 push-content">:        ﹨∕        ║▏　﹉﹊﹍</span><span class="push-ipdatetime"> 220.132.84.207 07/06
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">LostHeaven</span><span class="f3 push-content">:       ◢▆█▆◣   ║▏</span><span class="push-ipdatetime"> 220.132.84.207 07/06
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">LostHeaven</span><span class="f3 push-content">: ﹍﹎  ◤███◥   ║▏</span><span class="push-ipdatetime"> 220.132.84.207 07/06
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">LostHeaven</span><span class="f3 push-content">:      /／▂★▂＼\  ║▏¯￣﹉﹊</span><span class="push-ipdatetime"> 220.132.84.207 07/06
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">LostHeaven</span><span class="f3 push-content">:     ◢ -◎－◎- ◣ ║▏   ﹊﹍﹎</span><span class="push-ipdatetime"> 220.132.84.207 07/06
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">LostHeaven</span><span class="f3 push-content">:﹊﹍   \   皿   /   ║▏</span><span class="push-ipdatetime"> 220.132.84.207 07/06
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">LostHeaven</span><span class="f3 push-content">:    ／/◣  ︶  ◢\＼║▏ ¯￣﹉﹊</span><span class="push-ipdatetime"> 220.132.84.207 07/06
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">LostHeaven</span><span class="f3 push-content">:  ／ / ▅▆▇▆▅ \ ║▏  ﹊﹍﹍</span><span class="push-ipdatetime"> 220.132.84.207 07/06
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">LostHeaven</span><span class="f3 push-content">:／  / ｜ ⅢⅢⅢ ｜ \ ▌＼   ﹍</span><span class="push-ipdatetime"> 220.132.84.207 07/06
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">LostHeaven</span><span class="f3 push-content">:   /  ｜        ｜   ●  ＼  ﹊﹍﹎</span><span class="push-ipdatetime"> 220.132.84.207 07/06
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">LostHeaven</span><span class="f3 push-content">:  /    ＝＝∮＝＝    ▌</span><span class="push-ipdatetime"> 220.132.84.207 07/06
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">LostHeaven</span><span class="f3 push-content">:     ／          ＼  ﹊﹍﹊ 達斯.柏油</span><span class="push-ipdatetime"> 220.132.84.207 07/06
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">yanli2</span><span class="f3 push-content">:推!</span><span class="push-ipdatetime">    61.66.21.31 07/07
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">dio0204</span><span class="f3 push-content">:    ╭───┐    ╭─────────╮</span><span class="push-ipdatetime"> 220.139.16.173 07/14
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">dio0204</span><span class="f3 push-content">:    │ ___㊣ ㄟ   │ 各位戰吧！       │</span><span class="push-ipdatetime"> 220.139.16.173 07/14
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">dio0204</span><span class="f3 push-content">:     █    ◥▌   ＜ 輸的人要陪我~    │</span><span class="push-ipdatetime"> 220.139.16.173 07/14
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">dio0204</span><span class="f3 push-content">:     ◤□︵□▌   │ 騎洨綿羊~趕鈴羊~ │</span><span class="push-ipdatetime"> 220.139.16.173 07/14
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">dio0204</span><span class="f3 push-content">:     ╲  口 ／  ○╰─────────╯</span><span class="push-ipdatetime"> 220.139.16.173 07/14
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">dio0204</span><span class="f3 push-content">:     ◣  ︺ ◣√      ╭───────╮</span><span class="push-ipdatetime"> 220.139.16.173 07/14
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">dio0204</span><span class="f3 push-content">:     ▏≒ㄟ◎尸       │咩！不要趕我~ │</span><span class="push-ipdatetime"> 220.139.16.173 07/14
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">dio0204</span><span class="f3 push-content">:    │  _﹨ V﹨ 　　  ╰V ──────╯</span><span class="push-ipdatetime"> 220.139.16.173 07/14
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">dio0204</span><span class="f3 push-content">:  ㄈ╰ ◣ ﹨ ︵       ╮╭   ◢██◣ζ</span><span class="push-ipdatetime"> 220.139.16.173 07/14
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">dio0204</span><span class="f3 push-content">: √≡   ▌√ ㄟ＞     ﹨∕ ◢████</span><span class="push-ipdatetime"> 220.139.16.173 07/14
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">dio0204</span><span class="f3 push-content">:\ ▂▃╰─╯﹨ 0）   ⊙≡⊙◤∥∥∥∥</span><span class="push-ipdatetime"> 220.139.16.173 07/14
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">dio0204</span><span class="f3 push-content">:   ︶         ︶       ￥    ㄍㄍ∥∥</span><span class="push-ipdatetime"> 220.139.16.173 07/14
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">lisine</span><span class="f3 push-content">:賣亂來啦XD</span><span class="push-ipdatetime">  220.142.47.47 07/20
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">fatshine</span><span class="f3 push-content">:推~~~啊~~~~</span><span class="push-ipdatetime">  210.64.176.74 07/20
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">fatshine</span><span class="f3 push-content">:推~~~啊~~~~</span><span class="push-ipdatetime">  210.64.176.74 07/20
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">fatshine</span><span class="f3 push-content">:推~~~啊~~~~</span><span class="push-ipdatetime">  210.64.176.74 07/20
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">fatshine</span><span class="f3 push-content">:推~~~啊~~~~</span><span class="push-ipdatetime">  210.64.176.74 07/20
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">fatshine</span><span class="f3 push-content">:推~~~啊~~~~</span><span class="push-ipdatetime">  210.64.176.74 07/20
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">yellowbooky</span><span class="f3 push-content">:...</span><span class="push-ipdatetime">  59.113.234.52 07/21
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">yellowbooky</span><span class="f3 push-content">: ││◢██◣   ┌──────────—ꈠ</span><span class="push-ipdatetime">  59.113.234.52 07/21
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">yellowbooky</span><span class="f3 push-content">: ││█    ◥▌ │這位先生，你的東西掉了ꈠ</span><span class="push-ipdatetime">  59.113.234.52 07/21
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">yellowbooky</span><span class="f3 push-content">:   │◤□︵□▌ ╱───────────ꈠ</span><span class="push-ipdatetime">  59.113.234.52 07/21
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">yellowbooky</span><span class="f3 push-content">:     ╲  △╱</span><span class="push-ipdatetime">  59.113.234.52 07/21
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">yellowbooky</span><span class="f3 push-content">:      ◤︺￣◤</span><span class="push-ipdatetime">  59.113.234.52 07/21
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">yellowbooky</span><span class="f3 push-content">:     ｜    ｜</span><span class="push-ipdatetime">  59.113.234.52 07/21
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">yellowbooky</span><span class="f3 push-content">:      ◤￣◥</span><span class="push-ipdatetime">  59.113.234.52 07/21
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">yellowbooky</span><span class="f3 push-content">:    ￣￣￣￣￣                  ◢██◣</span><span class="push-ipdatetime">  59.113.234.52 07/21
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">yellowbooky</span><span class="f3 push-content">:                                █     ｜</span><span class="push-ipdatetime">  59.113.234.52 07/21
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">yellowbooky</span><span class="f3 push-content">:                         冷    ｜ ＠  ＠</span><span class="push-ipdatetime">  59.113.234.52 07/21
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">yellowbooky</span><span class="f3 push-content">:                       ￣￣￣   ╲  ε╱</span><span class="push-ipdatetime">  59.113.234.52 07/21
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">yellowbooky</span><span class="f3 push-content">:                               ◢￣￣￣◤</span><span class="push-ipdatetime">  59.113.234.52 07/21
# </span></div>
# ...
# </span></div>
# <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">ken2318</span><span class="f3 push-content">:❶❷❸❹❺❻❼</span><span class="push-ipdatetime"> 09/13 21:36
# </span></div>
# <div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">love0147</span><span class="f3 push-content">
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">FranKang</span><span class="f3 push-content">:█ ｜＃;(皿)｜︴ξ╱￣￣￣￣╲│脫起胸動上友酒│</span><span class="push-ipdatetime"> 07/28 22:27
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">FranKang</span><span class="f3 push-content">:█▍＼___﹀／ ζ╱宅變妄想症'|│糞來膛貼樓置朋│</span><span class="push-ipdatetime"> 07/28 22:27
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">FranKang</span><span class="f3 push-content">:█_◢█▆▅◣_◢█████◣_/╰───────╯</span><span class="push-ipdatetime"> 07/28 22:27
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Cubicalex</span><span class="f3 push-content">:X                   ▄▂</span><span class="push-ipdatetime"> 08/17 18:01
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Cubicalex</span><span class="f3 push-content">:                   ██▂          ███</span><span class="push-ipdatetime"> 08/17 18:01
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Cubicalex</span><span class="f3 push-content">:                  ████▍     ◢██◤</span><span class="push-ipdatetime"> 08/17 18:01
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Cubicalex</span><span class="f3 push-content">:                ◢███◤      ███▌</span><span class="push-ipdatetime"> 08/17 18:01
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Cubicalex</span><span class="f3 push-content">:           █▇███◤        ████◣</span><span class="push-ipdatetime"> 08/17 18:01
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Cubicalex</span><span class="f3 push-content">:           ◥████   ▂    ██◤  ◥█◣</span><span class="push-ipdatetime"> 08/17 18:01
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Cubicalex</span><span class="f3 push-content">:                █████▊◢██       ◥█▆▄</span><span class="push-ipdatetime"> 08/17 18:01
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Cubicalex</span><span class="f3 push-content">:           ▂ ◢███◤ ▉ ██◤         ◥███</span><span class="push-ipdatetime"> 08/17 18:01
# </span></div>
# <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">joe1408</span><span class="f3 push-content">:</span><span class="push-ipdatetime"> 07/19 22:07
# </span></div>
# <div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">rad81712</span><span class="f3 push-content">:朝聖 2011</span><span class="push-ipdatetime"> 07/29 17:44
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">firestu</span><span class="f3 push-content">:</span><span class="push-ipdatetime"> 08/27 18:59
# </span></div>
# <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">shinelin830</span><span class="f3 push-content">:QQ</span><span class="push-ipdatetime"> 01/30 23:09
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">BOIAN05</span><span class="f3 push-content">:X1一任生日快樂</span><span class="push-ipdatetime"> 01/02 23:50
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">BOIAN05</span><span class="f3 push-content">:1正妹生日快樂</span><span class="push-ipdatetime"> 01/02 23:50
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">BOIAN05</span><span class="f3 push-content">:1超帥的正妹生日快樂</span><span class="push-ipdatetime"> 01/02 23:50
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">BOIAN05</span><span class="f3 push-content">:1生日快樂!!!!!!!!!!   大家都歐趴</span><span class="push-ipdatetime"> 01/02 23:50
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">BOIAN05</span><span class="f3 push-content">:1生日快樂     一任請吃消夜</span><span class="push-ipdatetime"> 01/02 23:50
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">YaPTT</span><span class="f3 push-content">: ㄏㄏ</span><span class="push-ipdatetime"> 12/18 15:29
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">letyoufree</span><span class="f3 push-content">: / smile</span><span class="push-ipdatetime"> 08/20 21:20
# </span></div>
# Processing article:  M.1049638506.A.993
# link https://www.ptt.cc/bbs/Hate/M.1049638506.A.993.html
# <div class="article-metaline"><span class="article-meta-tag">作者</span><span class="article-meta-value">lightthefire (我以為我的以為)</span></div>
# <div class="article-metaline"><span class="article-meta-tag">標題</span><span class="article-meta-value">幹你娘基八亂按什麼電玲啊幹</span></div>
# <div class="article-metaline"><span class="article-meta-tag">時間</span><span class="article-meta-value">Sun Apr  6 22:18:11 2003</span></div>
# <div class="article-metaline-right"><span class="article-meta-tag">看板</span><span class="article-meta-value">Hate</span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">IAMmim</span><span class="f3 push-content">:老娘  亮我火是女的喔?!</span><span class="push-ipdatetime">                       推  210.85.192.18 04/06
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Bluce</span><span class="f3 push-content">:火哥~你什麼時候閹了?!</span><span class="push-ipdatetime">                         推  61.225.20.199 04/06
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">YICHANCHUNG</span><span class="f3 push-content">:這隻是亮這火吧</span><span class="push-ipdatetime">                          推   61.216.42.76 04/06
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">lightthefire</span><span class="f3 push-content">:還不是一樣</span><span class="push-ipdatetime">                             推  210.85.192.18 04/06
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">lightmyfire</span><span class="f3 push-content">:嗯</span><span class="push-ipdatetime">                                      推 210.85.193.190 05/26
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Technician</span><span class="f3 push-content">:嗯個屁</span><span class="push-ipdatetime">                                   推202.178.167.225 06/08
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Audi8</span><span class="f3 push-content">:               看我一槍斃了你</span><span class="push-ipdatetime">                      218.161.7.63 11/28
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Audi8</span><span class="f3 push-content">:`， .　　　　              \</span><span class="push-ipdatetime">                       218.161.7.63 11/28
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Audi8</span><span class="f3 push-content">:   ζ '                     \</span><span class="push-ipdatetime">                      218.161.7.63 11/28
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Audi8</span><span class="f3 push-content">:             ‥‥…… ==﹃＿●</span><span class="push-ipdatetime">                     218.161.7.63 11/28
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Audi8</span><span class="f3 push-content">:      》                   ﹀|</span><span class="push-ipdatetime">                     218.161.7.63 11/28
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Audi8</span><span class="f3 push-content">:︿○&gt;ㄧ︾                   / \</span><span class="push-ipdatetime">                    218.161.7.63 11/28
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Audi8</span><span class="f3 push-content">:              ╮</span><span class="push-ipdatetime">                                   218.161.7.63 11/28
# </span></div>
# <div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Audi8</span><span class="f3 push-content">: ╭○      ＼ ○═══════  ＃  ＃</span><span class="push-ipdatetime">             218.161.7.63 11/28
# </span></div>

# %%
def parse(link, article_id):
    print('Processing article: ', article_id)
    
    resp = requests.get(url = link, cookies={'over18':'1'})
    # status_code=200 is success, so if not success will return error e.g. 404 not found
    if resp.status_code != 200:
        print('invalid url: ', resp.url)
        return {'error': 'invalid url'}
    
    soup = BeautifulSoup(resp.text, 'html.parser')
    main_content = soup.find(id = 'main-content')
    # metaline includes of author, title and datetime
    metas = main_content.select('div.article-metaline')
    
    author = ''
    title = ''
    date = ''
    
    if metas:
        author = metas[0].select('span.article-meta-value')[0].text if metas[0].select('span.article-meta-value')[0] else author
        title = metas[1].select('span.article-meta-value')[1].text if metas[1].select('span.article-meta-value')[1] else title
        date = metas[2].select('span.article-meta-value')[2].text if metas[2].select('span.article-meta-value')[2] else date
        # remove meta nodes
        for meta in metas:
            meta.extract()
        for meta in main_content.select('div.article-metaline-right'):
            meta.extract()
    # remove and keep push nodes
    for push in main_content.find_all('div', class_='push'):
        push.extract()
    
    # 移除 '※ 發信站:' (starts with u'\u203b'), '◆ From:' (starts with u'\u25c6'), 空行及多餘空白
    # 保留英數字, 中文及中文標點, 網址, 部分特殊符號
    filtered = [ v for v in main_content.stripped_strings if v[0] not in [u'※', u'◆'] and v[:2] not in [u'--'] ]
    expr = re.compile(u(r'[^\u4e00-\u9fa5\u3002\uff1b\uff0c\uff1a\u201c\u201d\uff08\uff09\u3001\uff1f\u300a\u300b\s\w:/-_.?~%()]'))
    for i in range(len(filtered)):
        filtered[i] = re.sub(expr, '', filtered[i])

    filtered = [_f for _f in filtered if _f]  # remove empty strings
    filtered = [x for x in filtered if article_id not in x]  # remove last line containing the url of the article
    content = ' '.join(filtered)
    content = re.sub(r'(\s)+', ' ', content)
    
    data = {
        'url': link,
        'title': title,
        'author': author,
        'date': date,
        'content': content
    }
    
    return data

# %%
meta
# Out:
# <div class="article-metaline-right"><span class="article-meta-tag">看板</span><span class="article-meta-value">Hate</span></div>

# %%
#### TEST CODE #####
resp = requests.get(url = 'https://www.ptt.cc/bbs/Hate/M.1581756353.A.DC1.html', cookies={'over18':'1'})
# status_code=200 is success, so if not success will return error e.g. 404 not found
if resp.status_code != 200:
    print('invalid url: ', resp.url)

soup = BeautifulSoup(resp.text, 'html.parser')
main_content = soup.find(id = 'main-content')
# metaline includes of author, title and datetime
metas = main_content.select('div.article-metaline')
#author = ''
#title = ''
#date = ''
#if metas:
#    author = metas[0].select('span.article-meta-value')[0].string if metas[0].select('span.article-meta-value')[0] else author
#    title = metas[1].select('span.article-meta-value')[0].string if metas[1].select('span.article-meta-value')[0] else title
#    date = metas[2].select('span.article-meta-value')[0].string if metas[2].select('span.article-meta-value')[0] else date#
#
    # remove meta nodes
#    for meta in metas:
#        meta.extract()
#    for meta in main_content.select('div.article-metaline-right'):
        meta.extract()
# Out:
#   File "<ipython-input-106-b2a7732445a6>", line 23
#     meta.extract()
#     ^
# IndentationError: unexpected indent

# %%
#### TEST CODE #####

from six import u

article_id = 'M.1581756353.A.DC1'

# remove and keep push nodes
pushes = main_content.find_all('div', class_='push')
for push in pushes:
    push.extract()
            
filtered = [ v for v in main_content.stripped_strings if v[0] not in [u'※', u'◆'] and v[:2] not in [u'--'] ]
expr = re.compile(u(r'[^\u4e00-\u9fa5\u3002\uff1b\uff0c\uff1a\u201c\u201d\uff08\uff09\u3001\uff1f\u300a\u300b\s\w:/-_.?~%()]'))
for i in range(len(filtered)):
    filtered[i] = re.sub(expr, '', filtered[i])

filtered = [_f for _f in filtered if _f]  # remove empty strings
print(filtered)
filtered = [x for x in filtered if article_id not in x]  # remove last line containing the url of the article
content = ' '.join(filtered)
print(content)
content = re.sub(r'(\s)+', ' ', content)
print(content)
# Out:
# ['小弟剛剛做了一個可怕的噩夢\n\n夢中小弟被人設計陷害\n\n堅持自己是真的遇到這種爛事\n\n可是沒有人相信我\n\n小弟開始懷疑自己是不是做夢夢到\n但我堅持不是假的\n\n結果醒來以後發現 QQ\n\n', 'https://www.ptt.cc/bbs/Hate/M.1581756353.A.DC1.html']
# 小弟剛剛做了一個可怕的噩夢
#
# 夢中小弟被人設計陷害
#
# 堅持自己是真的遇到這種爛事
#
# 可是沒有人相信我
#
# 小弟開始懷疑自己是不是做夢夢到
# 但我堅持不是假的
#
# 結果醒來以後發現 QQ
#
#
# 小弟剛剛做了一個可怕的噩夢 夢中小弟被人設計陷害 堅持自己是真的遇到這種爛事 可是沒有人相信我 小弟開始懷疑自己是不是做夢夢到 但我堅持不是假的 結果醒來以後發現 QQ
